# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('data/young_survey.csv')

# %%
df
# Out:
#        Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# Music
# 5.0                         3.0    2.0   1.0      2.0              2.0
# 4.0                         4.0    2.0   1.0      1.0              1.0
# 5.0                         5.0    2.0   2.0      3.0              4.0
# 5.0                         3.0    2.0   1.0      1.0              1.0
# 5.0                         3.0    4.0   3.0      2.0              4.0
# ...                         ...    ...   ...      ...              ...
# 5.0                         2.0    5.0   2.0      2.0              5.0
# 4.0                         4.0    5.0   1.0      3.0              4.0
# 4.0                         3.0    1.0   1.0      2.0              2.0
# 5.0                         3.0    3.0   3.0      1.0              3.0
# 5.0                         5.0    4.0   3.0      2.0              3.0
#
#        Musical  Pop  Rock  Metal or Hardrock  Punk  ...  Spending on looks  \
# ...

# %%
# 음악과 관련된 평가 열들만 추출
music = df.iloc[:, :19]
music
# Out:
#        Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# Music
# 5.0                         3.0    2.0   1.0      2.0              2.0
# 4.0                         4.0    2.0   1.0      1.0              1.0
# 5.0                         5.0    2.0   2.0      3.0              4.0
# 5.0                         3.0    2.0   1.0      1.0              1.0
# 5.0                         3.0    4.0   3.0      2.0              4.0
# ...                         ...    ...   ...      ...              ...
# 5.0                         2.0    5.0   2.0      2.0              5.0
# 4.0                         4.0    5.0   1.0      3.0              4.0
# 4.0                         3.0    1.0   1.0      2.0              2.0
# 5.0                         3.0    3.0   3.0      1.0              3.0
# 5.0                         5.0    4.0   3.0      2.0              3.0
#
#        Musical  Pop  Rock  Metal or Hardrock  Punk  Hiphop, Rap  Reggae, Ska  \
# Music
# ...

# %%
# music 평가장르별 상관관계를 히트맵 시각화
sns.heatmap(music.corr())

# %%
df.corr()['Age'].sort_values(ascending=False) # 'Age'와 가장 연관이 있는 순서로 나열
# 위의 히트맵에서 하나의 열만 추출해서 나열한다고 생각
# Out:
# Age                        1.000000
# Weight                     0.238893
# Elections                  0.212319
# Prioritising workload      0.156256
# Reliability                0.148141
#                              ...
# Mood swings               -0.111890
# Getting up                -0.119888
# Questionnaires or polls   -0.128187
# Shopping centres          -0.133800
# Changing the past         -0.146895
# Name: Age, Length: 138, dtype: float64

# %% [markdown]
# # Question1
# 대위는 신촌에서 대학생들을 대상으로 브런치 카페를 운영합니다.
#
# 손님들의 취향에 딱 맞는 음악을 틀고 싶은데요. 브런치 카페이기 때문에, 일찍 일어나는 사람들이 좋아
# 할 만한 음악이 무엇인지 분석해 보려고 합니다.
#
# 주어진 데이터(다운로드)의 “Getting up”이라는 column을 보면 사람들이 아침에 일어나는 걸 얼마나 어
# 려워하는지 알 수 있습니다. 5라고 대답한 사람들은 아침에 일어나는 걸 아주 어려워 하는 사람들이고, 1
# 이라고 대답한 사람들은 아침에 쉽게 일어난다는 거죠.
#
# 이 데이터로 봤을 때, 아침에 일찍 일어나는 사람들이 가장 좋아할 만한 음악 장르는 무엇인가요?

# %%
df
# Out:
#        Slow songs or fast songs  Dance  Folk  Country  Classical music  \
# Music
# 5.0                         3.0    2.0   1.0      2.0              2.0
# 4.0                         4.0    2.0   1.0      1.0              1.0
# 5.0                         5.0    2.0   2.0      3.0              4.0
# 5.0                         3.0    2.0   1.0      1.0              1.0
# 5.0                         3.0    4.0   3.0      2.0              4.0
# ...                         ...    ...   ...      ...              ...
# 5.0                         2.0    5.0   2.0      2.0              5.0
# 4.0                         4.0    5.0   1.0      3.0              4.0
# 4.0                         3.0    1.0   1.0      2.0              2.0
# 5.0                         3.0    3.0   3.0      1.0              3.0
# 5.0                         5.0    4.0   3.0      2.0              3.0
#
#        Musical  Pop  Rock  Metal or Hardrock  Punk  ...  Spending on looks  \
# ...

# %%
brunch_df = df.corr()['Getting up']

# %%
brunch_df[: 19].sort_values(ascending=True)

# %% [markdown]
# 해석: +5가 일어나기 힘든 사람, +1가 일찍 일어나는 사람이다.
#
# 상관계수가 높을수록 일어나기 힘든사람(5) 에 근접함을 알 수 있고,
#
# 상관계수가 낮을수록 일찍 일어나는 사람(1)에 근접함을 알 수 있다.

# %% [markdown]
# # Question2
# 경영학과 3학년이 된 영준이는 스타트업을 준비하고 있습니다.
# 사업 아이템을 고민하면서, 나름대로 가설을 몇 개 세워봤습니다.
#
# 악기를 다루는 사람들은 시 쓰기를 좋아하는 경향이 있을 것이다.
#
# 외모에 돈을 많이 투자하는 사람들은 브랜드 의류를 선호할 것이다.
#
# 메모를 자주 하는 사람들은 새로운 환경에 쉽게 적응할 것이다.
#
# 워커홀릭들은 건강한 음식을 먹으려는 경향이 있을 것이다.
#
# 이 내용을 사업 아이템으로 확장하기 전에, 데이터를 통해 가설을 검증해보려고 하는데요.
# 설문조사 데이터(다운로드)를 바탕으로, 가장 가능성이 낮은 가설을 골라보세요.
#
#
# 이 가설과 관련이 있는 column은 다음과 같습니다.
#
#
# Branded clothing: 나는 브랜드가 없는 옷보다 브랜드가 있는 옷을 선호한다.
#
# Healthy eating: 나는 건강하거나 품질이 좋은 음식에는 기쁘게 돈을 더 낼 수 있다.
#
# Musical instruments: 나는 악기 연주에 관심이 많다.
#
# New environment: 나는 새 환경에 잘 적응하는 편이다.
#
# Prioritising workload: 나는 일을 미루지 않고 즉시 해결해버리려고 한다.
#
# Spending on looks: 나는 내 외모에 돈을 많이 쓴다.
#
# Workaholism: 나는 여가 시간에 공부나 일을 자주 한다.
#
# Writing: 나는 시 쓰기에 관심이 많다.
#
# Writing notes: 나는 항상 메모를 한다.

# %% [markdown]
# #### 1. 악기를 다루는 사람들은 시 쓰기를 좋아하는 경향이 있을 것이다.

# %%
musical = df.corr()['Musical instruments'].sort_values(ascending=True)
musical['Writing']
# Out:
# 0.34381621439042986

# %%
df.corr().loc['Musical instruments', 'Writing']
# Out:
# 0.34381621439042986

# %% [markdown]
# #### 2. 외모에 돈을 많이 투자하는 사람들은 브랜드 의류를 선호할 것이다.

# %%
look = df.corr()['Spending on looks'].sort_values(ascending=True)
look['Branded clothing']
# Out:
# 0.4183989446458914

# %%
df.corr().loc['Spending on looks', 'Branded clothing']
# Out:
# 0.4183989446458914

# %% [markdown]
# #### 3. 메모를 자주 하는 사람들은 새로운 환경에 쉽게 적응할 것이다.

# %%
notes = df.corr()['Writing notes'].sort_values(ascending=True)
notes['New environment']
# Out:
# -0.07939652994810564

# %%
df.corr().loc['Writing notes', 'New environment']
# Out:
# -0.07939652994810564

# %% [markdown]
# #### 4. 워커홀릭들은 건강한 음식을 먹으려는 경향이 있을 것이다.

# %%
work = df.corr()['Workaholism'].sort_values(ascending=True)
work['Healthy eating']
# Out:
# 0.23864443283866651

# %%
df.corr().loc['Workaholism', 'Healthy eating']
# Out:
# 0.23864443283866651

# %% [markdown]
# 해석: 3번의 경우가 가장 상관관계가 낮으므로, 가능성이 낮다고 볼 수 있다.
